# %%
import pandas as pd

# %%
data = pd.read_csv("E:\\task\\大论文\\代码\\MaoerExperiment/data/0101_0131_all_feature_involved_dy.csv")

# %%
data.head()
# Out:
#    user_name_len  user_name_has_chinese  user_name_has_english  \
# 0             18                      0                      0
# 1             25                      0                      0
# 2             25                      0                      0
# 3             25                      0                      0
# 4             25                      0                      0
#
#    user_intro_len  user_intro_has_chinese  user_intro_has_english  \
# 0             NaN                       0                       0
# 1            60.0                       1                       0
# 2            60.0                       1                       0
# 3            60.0                       1                       0
# 4            60.0                       1                       0
#
#    user_icon_is_default  user_has_submit_sound_or_darma  user_grade  \
# 0                     0                               0           1
# ...

# %%
for idx,col in enumerate(data.columns):
    print(f"{idx} : {col}, {data[col].dtype}, {data[col][1]}")
# Out:
# 0 : user_name_len, int64, 25
# 1 : user_name_has_chinese, int64, 0
# 2 : user_name_has_english, int64, 0
# 3 : user_intro_len, float64, 60.0
# 4 : user_intro_has_chinese, int64, 1
# 5 : user_intro_has_english, int64, 0
# 6 : user_icon_is_default, int64, 0
# 7 : user_has_submit_sound_or_darma, int64, 0
# 8 : user_grade, int64, 1
# 9 : user_fish_num, int64, 14252
# 10 : user_follower_num, int64, 20
# 11 : user_fans_num, int64, 0
# 12 : user_has_organization, int64, 0
# 13 : user_submit_sound_num, int64, 0
# 14 : user_submit_drama_num, float64, 0.0
# 15 : user_subscribe_drama_num, float64, 265.0
# 16 : user_subscribe_channel_num, int64, 0
# 17 : user_favorite_album_num, int64, 0
# 18 : user_image_num, float64, 0.0
# 19 : user_submit_danmu_drama_completed_num_now, int64, 0
# 20 : user_submit_danmu_drama_total_view_num, float64, 8461.0
# 21 : user_submit_danmu_drama_max_view_num, float64, 31969401.0
# 22 : user_submit_danmu_drama_min_view_num, float64, 155370.0
# ...
